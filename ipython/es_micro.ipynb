# %% [markdown]
# # Edge sampling - microscopic results
#
# * We investigate the sequence of edges for a temporally growing network
# * We investigate the ratio of different types of edges as the function of the size of the network

# %%
# %matplotlib inline
import sys
sys.path.insert(0,"../python")
from plot.plot import Plot
from plot.edge_sampling_parser import EdgeSamplingParser
from plot.edge_sampling import EdgeSampling
Plot().set()
parser =  EdgeSamplingParser()
data = parser.run("/home/rpalovics/Densification/paths/")

# %% [markdown]
# ## Ratio of different types of edges
#
# * Plots:
#    * Left: original network
# * Types of edges:
#     * influence: when one of the nodes on the new edge was already part of the network
#     * random: when both nodes on the new edge are new incoming nodes in the net
#     * homophily: when both nodes were already part of the netwowk
#     * triangle:  case of homophily, when the initial distance is 2 of the connecting nodes (triangle)

# %%
edge_sampling = EdgeSampling(data)
edge_sampling.plot()
